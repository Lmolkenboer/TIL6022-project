# %% [markdown]
# Plots Bas

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

# %%
t = pd.read_csv('Data_online_shopping_total.csv', delimiter = ';', index_col = 0)
t.head()
m = pd.read_csv('Data_online_shopping_men.csv', delimiter = ';', index_col = 0)
w = pd.read_csv('Data_online_shopping_women.csv', delimiter = ';', index_col = 0)
t.head()
# Out:
#          Totaal online aankopen Kleding of sportartikelen   \
# Perioden
# 2012                         64                       31,2
# 2013                         68                       36,7
# 2014                       69,7                       40,5
# 2015                         70                       42,4
# 2016                       73,3                       47,9
#
#          Boeken, tijdschriften en kranten   \
# Perioden
# 2012                                  22,9
# 2013                                  27,5
# 2014                                  28,7
# 2015                                  28,2
# 2016                                  29,1
#
#          Soft-/ hardware en elektronische benodig  \
# Perioden
# 2012                                         12,8
# 2013                                         16,6
# 2014                                         18,3
# 2015                                         24,8
# 2016                                         26,1
#
#          Huishoudelijke goederen en apparaten
# Perioden
# 2012                                     15,8
# 2013                                     18,2
# 2014                                     23,2
# 2015                                     23,9
# 2016                                     28,6

# %%
y1 = t['Totaal online aankopen']
y2 = m['Totaal online aankopen']
y3 = w['Totaal online aankopen']

plt.plot(x,y1,label='Total', marker = 'o')
plt.plot(x,y2,label='Men', marker = 'o')
plt.plot(x,y3,label='Women', marker = 'o')
plt.xlabel('Years')
plt.ylabel('% of people (above 12 y.o.) old buying online')
plt.legend()

# %%
y1 =
